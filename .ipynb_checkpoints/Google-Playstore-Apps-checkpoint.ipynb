# %%
# imports
import pandas as pd

# %%
# load data
url = 'https://media.githubusercontent.com/media/gauthamp10/Google-Playstore-Dataset/main/Google-Playstore.csv'

df = pd.read_csv(url)
print(df.shape)
df.head()
# Out:
# (603047, 23)
#                                           App Name  \
# 0        foodpanda - Local Food & Grocery Delivery
# 1  Tripadvisor Hotel, Flight & Restaurant Bookings
# 2                       Safeway Delivery & Pick Up
# 3                              My CookBook Ad-Free
# 4                 Talabat: Food & Grocery Delivery
#
#                          App Id        Category  Rating  Rating Count  \
# 0  com.global.foodpanda.android    Food & Drink     4.4     1258493.0
# 1   com.tripadvisor.tripadvisor  Travel & Local     4.4     1360172.0
# 2              com.safeway.shop        Shopping     4.2        5532.0
# 3                fr.cookbookpro    Food & Drink     4.7        2531.0
# 4                   com.talabat    Food & Drink     4.4      197649.0
#
#        Installs  Minimum Installs  Maximum Installs   Free  Price  ...  \
# 0   10,000,000+        10000000.0          48828081   True   0.00  ...
# 1  100,000,000+       100000000.0         371284181   True   0.00  ...
# ...

# %%
# any null values?
df.isnull().sum()
# Out:
# App Name                  1
# App Id                    0
# Category                  0
# Rating                 3760
# Rating Count           3760
# Installs                172
# Minimum Installs        172
# Maximum Installs          0
# Free                      0
# Price                     0
# Currency                181
# Size                      0
# Minimum Android         491
# Developer Id              2
# Developer Website    179264
# Developer Email          37
# Released              32278
# Last Updated              0
# Content Rating            0
# Privacy Policy        85385
# Ad Supported              0
# In App Purchases          0
# Editors Choice            0
# dtype: int64

# %%
# list columns
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice'],
#       dtype='object')

# %%
# top 50 apps by Rating Count
df.sort_values(by='Rating Count', ascending=False).head(50)
# Out:
#                                                  App Name  \
# 211743                                 WhatsApp Messenger
# 211744                                          Instagram
# 211690                                           Facebook
# 34214                                             YouTube
# 211741           Messenger – Text and Video Chat for Free
# 39144                           Garena Free Fire: Rampage
# 14439                                      Clash of Clans
# 211701                                     Subway Surfers
# 11411                        PUBG MOBILE - NEW MAP: LIVIK
# 26919                                Google Play services
# 153325                                   Candy Crush Saga
# 64216                                        Clash Royale
# 170023                                      Google Photos
# 211717                                           Snapchat
# 211747                             TikTok - Make Your Day
# ...

# %%
# top 50 apps by installs
df.sort_values(by='Installs', ascending=False).head(50)
# Out:
#                                                  App Name  \
# 211697  Spotify: Listen to new music, podcasts, and songs
# 99082    Flipboard - Latest News, Top Stories & Lifestyle
# 87474                             HP Print Service Plugin
# 99661               Messenger Lite: Free Calls & Messages
# 38                                  Uber - Request a ride
# 11734                                        Temple Run 2
# 179626                          Samsung Link (Terminated)
# 179629                     Samsung Security Policy Update
# 179633                        [Samsung] Always On Display
# 99216   LinkedIn: Jobs, Business News & Social Networking
# 87169                         Microsoft SwiftKey Keyboard
# 170017                        Google Play Services for AR
# 170014                      Google Keep - Notes and Lists
# 175496   PicsArt Photo Editor: Pic, Video & Collage Maker
# 14439                                      Clash of Clans
# ...

# %%
# how many of each threshold of installs
df['Installs'].value_counts()
# Out:
# 10,000+           109335
# 1,000+            106275
# 100+               77177
# 100,000+           59172
# 5,000+             50315
# 500+               40268
# 50,000+            37678
# 10+                35114
# 50+                23629
# 1,000,000+         20389
# 500,000+           15365
# 1+                  8100
# 5+                  8082
# 5,000,000+          4388
# 10,000,000+         4332
# 0+                  2168
# 50,000,000+          598
# 100,000,000+         388
# 500,000,000+          48
# 1,000,000,000+        41
# 5,000,000,000+        13
# Name: Installs, dtype: int64

# %%
# category
df['Category'].value_counts(normalize=True).head(15)
# Out:
# Education            0.126057
# Books & Reference    0.078672
# Music & Audio        0.066428
# Entertainment        0.064944
# Tools                0.064264
# Lifestyle            0.057078
# Business             0.046202
# Personalization      0.045341
# Productivity         0.033546
# Health & Fitness     0.032192
# Finance              0.031805
# Travel & Local       0.028280
# News & Magazines     0.024945
# Shopping             0.023474
# Sports               0.022234
# Name: Category, dtype: float64

# %%
# content rating
df['Content Rating'].value_counts(normalize=True)
# Out:
# Everyone           0.892486
# Teen               0.070832
# Mature 17+         0.019123
# Everyone 10+       0.017476
# Unrated            0.000046
# Adults only 18+    0.000036
# Name: Content Rating, dtype: float64

# %%
# free to download
df['Free'].value_counts(normalize=True)
# Out:
# True     0.948158
# False    0.051842
# Name: Free, dtype: float64

# %%
# ad supported
df['Ad Supported'].value_counts(normalize=True)
# Out:
# True     0.543079
# False    0.456921
# Name: Ad Supported, dtype: float64

# %%
# in app purchases
df['In App Purchases'].value_counts(normalize=True)
# Out:
# False    0.866505
# True     0.133495
# Name: In App Purchases, dtype: float64

# %%
# editors choice
df['Editors Choice'].value_counts(normalize=True)
# Out:
# False    0.998597
# True     0.001403
# Name: Editors Choice, dtype: float64
